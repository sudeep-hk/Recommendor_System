# %% [markdown]
# # import data and lib

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, pairwise_distances
from sklearn.model_selection import train_test_split

# %%
#read rating file
ratings=pd.read_csv('train.csv')

#article info
article_info=pd.read_csv('article_info.csv')

#test file
test=pd.read_csv('test.csv')

# %%
article_info.head()
# Out:
#    article_id     website                                              title  \
# 0        1025  uxmovement  Comment concevoir une procédure pas à pas que ...
# 1        2328    endeavor  Ressources humaines? Seulement si vous optez p...
# 2        2469    linkedin           Deux motions de vente différentes. . . .
# 3        2590  googleblog  Apprentissage large et profond: mieux avec Ten...
# 4         697       infoq              Agile: manque de compétences en tests
#
#                                              content
# 0  par anthony le 18/07/16 à 8h02 Si une nouvelle...
# 1  «Ambassadeurs», «avocats», «porte-parole» d'un...
# 2  J'ai passé pas mal de temps récemment avec des...
# 3  "Apprenez les règles comme un pro, afin de pou...
# 4  Fran O'Hara, directeur et consultant principal...

# %%
test
# Out:
#       user_id  article_id
# 0           1        2607
# 1           1        1445
# 2           1         911
# 3           1         857
# 4           1        2062
# ...       ...         ...
# 7238     1087        2089
# 7239     1087         504
# 7240     1087        1801
# 7241     1087         967
# 7242     1087         857
#
# [7243 rows x 2 columns]

# %%
ratings.head()
# Out:
#    user_id  article_id  rating
# 0        1         456       1
# 1        1        2934       1
# 2        1          82       1
# 3        1        1365       1
# 4        1         221       1

# %% [markdown]
# # Merge data set for organised data

# %%
ratings=ratings.merge(article_info[['article_id','title']],how='left',left_on='article_id',right_on='article_id')

# %%
ratings
# Out:
#        user_id  article_id  rating  \
# 0            1         456       1
# 1            1        2934       1
# 2            1          82       1
# 3            1        1365       1
# 4            1         221       1
# ...        ...         ...     ...
# 16726     1087        2242       1
# 16727     1087         419       1
# 16728     1087         784       1
# 16729     1087        1249       1
# 16730     1087        1692       1
#
#                                                    title
# 0      Obtenez 6 mois d'accès à Pluralsight, la plus ...
# 1      La plateforme cloud de Google est désormais un...
# 2            La technologie derrière les photos d'aperçu
# 3      Les VM préemptives de Google Cloud Platform so...
# 4      Ray Kurzweil: Le monde ne se détériore pas - n...
# ...                                                  ...
# 16726      Optimiser l'utilisation de la mémoire Arduino
# 16727  Le plan national de l'Internet des objets sort...
# 16728  Nintendo sortira Mini NES avec 30 jeux préchar...
# 16729  Coût d'erreur - Cinq raisons d'investir dans l...
# 16730  Tabs vs Spaces: comment ils écrivent Java sur ...
#
# [16731 rows x 4 columns]

# %%
ratings['rating'].max()
# Out:
# 5

# %%
ratings.columns
# Out:
# Index(['user_id', 'article_id', 'rating', 'title'], dtype='object')

# %%
#ratings['article']=ratings['article_id'].map(str)+str(':')+ratings['title'].map(str)

# %%
ratings=ratings.drop(['title'],axis=1)

# %%
ratings
# Out:
#        user_id  article_id  rating
# 0            1         456       1
# 1            1        2934       1
# 2            1          82       1
# 3            1        1365       1
# 4            1         221       1
# ...        ...         ...     ...
# 16726     1087        2242       1
# 16727     1087         419       1
# 16728     1087         784       1
# 16729     1087        1249       1
# 16730     1087        1692       1
#
# [16731 rows x 3 columns]

# %% [markdown]
# # Creating train,test and split

# %%
#assisgn X as original dataset: to prevent any change in original dataset
X=ratings.copy()
X_train, X_valid=train_test_split(X,test_size=0.25,random_state=50)

# %%
X_valid
# Out:
#        user_id  article_id  rating
# 10236      647         319       1
# 5272       383         944       1
# 15689     1011        1433       1
# 15308      989        2645       1
# 9228       584        2094       1
# ...        ...         ...     ...
# 12103      749        1308       1
# 4574       330         110       1
# 8003       522        1011       1
# 9768       616          17       1
# 8265       529         790       1
#
# [4183 rows x 3 columns]

# %%
#function to calculate RMSE for fast execution
def rmse(y_true,y_pred):
    return np.sqrt(mean_squared_error(y_true,y_pred))

# %% [markdown]
# # Using surprise library for prediction

# %%
from surprise import Dataset, Reader
from surprise.model_selection import GridSearchCV
from surprise.prediction_algorithms import KNNWithMeans

# %%
#surprise lib understnds the data in defined format****IMP***
reader=Reader(rating_scale=(1,5))
data=Dataset.load_from_df(X_train[['user_id','article_id','rating']],reader)

# %% [markdown]
# # Grid search for the hyperparameter tuning

# %%
param_grid={"k":list(range(1,70,5)),"sim_options":{"name":["cosine","pearson"]}}

gs = GridSearchCV(KNNWithMeans, 
                  param_grid, 
                  measures=['rmse'], 
                  cv=5, 
                  n_jobs = -1)

gs.fit(data)
#Printing the best score
print(gs.best_score['rmse'])

#Printing the best set of parameters
print(gs.best_params['rmse'])
# Out:
# 0.9982913285260275
# {'k': 6, 'sim_options': {'name': 'pearson', 'user_based': True}}

# %% [markdown]
# # Fit the model

# %%
#Defining similarity measure as per the best parameters
sim_options = {'name': 'pearson'}

#Fitting the model on train data
model = KNNWithMeans(k = 46, sim_options = sim_options)

#Build full trainset will essentially fit the knnwithmeans on the complete train set instead of a part of it
#like we do in cross validation
model.fit(data.build_full_trainset())
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
#id pairs for test set
id_pairs = zip(X_valid['user_id'], X_valid['article_id'])

#Making predictions for test set using predict method from Surprise
[model.predict(uid = user, iid = article_id) for (user, article_id) in id_pairs]
# Out:
# [Prediction(uid=647, iid=319, r_ui=None, est=1.1904761904761905, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=383, iid=944, r_ui=None, est=1.05, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=1011, iid=1433, r_ui=None, est=1, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid=989, iid=2645, r_ui=None, est=1, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid=584, iid=2094, r_ui=None, est=1.2142857142857142, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=978, iid=1700, r_ui=None, est=1.0588235294117647, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=397, iid=122, r_ui=None, est=2.119047619047619, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=408, iid=1536, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=399, iid=979, r_ui=None, est=2.1818181818181817, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=608, iid=2839, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=641, iid=890, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=1076, iid=2781, r_ui=None, est=1.0105321507760532, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid=527, iid=1755, r_ui=None, est=1.0421052631578949, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid=910, iid=307, r_ui=None, est=1.6216216216216217, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=970, iid=624, r_ui=None, est=1.2222222222222223, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=376, iid=2871, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=563, iid=459, r_ui=None, est=1.445945945945946, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=518, iid=1810, r_ui=None, est=2.423076923076923, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=261, iid=2150, r_ui=None, est=1.3, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=506, iid=2781, r_ui=None, est=1.0685510755518126, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid=349, iid=1671, r_ui=None, est=1.894736842105263, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=690, iid=281, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=93, iid=2641, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=945, iid=481, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid
r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=362, iid=1562, r_ui=None, est=1.7, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=432, iid=2933, r_ui=None, est=1.8, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=39, iid=639, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=14, iid=1777, r_ui=None, est=1, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid=578, iid=2491, r_ui=None, est=3.4692307692307693, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid=624, iid=965, r_ui=None, est=1.625, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=265, iid=1716, r_ui=None, est=1.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=557, iid=2853, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=384, iid=2482, r_ui=None, est=1.4565667835511635, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=1035, iid=840, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=563, iid=2361, r_ui=None, est=1, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=309, iid=1980, r_ui=None, est=1.1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=507, iid=490, r_ui=None, est=1.4565667835511635, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=414, iid=2781, r_ui=None, est=1.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=695, iid=2970, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=148, iid=1025, r_ui=None, est=1.7633053221288515, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid=441, iid=614, r_ui=None, est=1.1481481481481481, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=1042, iid=2314, r_ui=None, est=1.35, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=232, iid=2155, r_ui=None, est=1.7142857142857142, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=53, iid=2903, r_ui=None, est=2.6965601965601964, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid=142, iid=2011, r_ui=None, est=1.2727272727272727, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=494, iid=1149, r_ui=None, est=1.972972972972973, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=749, iid=719, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=642, iid=2669, r_ui=None, est=1.5714285714285714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=836, iid=2492, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=825, iid=1536, r_ui=None, est=1.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=563, iid=2488, r_ui=None, est=1.445945945945946, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=212, iid=1597, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=852, iid=867, r_ui=None, est=1.2083333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=504, iid=1769, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=505, iid=2400, r_ui=None, est=2.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=698, iid=467, r_ui=None, est=1.5045871559633028, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=829, iid=434, r_ui=None, est=1.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=726, iid=1357, r_ui=None, est=1.4230769230769231, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=741, iid=712, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=913, iid=1645, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=175, iid=2409, r_ui=None, est=1.3333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=193, iid=1360, r_ui=None, est=1.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=664, iid=389, r_ui=None, est=1.896551724137931, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=855, iid=2255, r_ui=None, est=1.1428571428571428, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=503, iid=1723, r_ui=None, est=1.912621359223301, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=59, iid=1928, r_ui=None, est=1.8, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=890, iid=468, r_ui=None, est=1.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=937, iid=910, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=726, iid=1465, r_ui=None, est=1.4230769230769231, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=253, iid=911, r_ui=None, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=185, iid=1857, r_ui=None, est=1.0689655172413792, details={'actual_k': 0, 'was_impossible': False}),
#  ...]

# %%
#id pairs for test set
id_pairs = zip(X_valid['user_id'], X_valid['article_id'])

#Making predictions for test set using predict method from Surprise
y_pred = [model.predict(uid = user, iid = movie)[3] for (user, movie) in id_pairs]

#Actual rating values for test set
y_true = X_valid['rating']

# Checking performance on test set
rmse(y_true, y_pred)
# Out:
# 1.0156959255885387

# %%
#prediction using test dataset
#id pairs for test set
id_pairs = zip(test['user_id'], test['article_id'])

#Making predictions for test set using predict method from Surprise
y_pred = [model.predict(uid = user, iid = movie)[3] for (user, movie) in id_pairs]

# %%
y_pred=pd.DataFrame({"ratings_test":y_pred})

# %%
y_pred
# Out:
#       ratings_test
# 0         1.000000
# 1         1.793744
# 2         1.363636
# 3         1.363636
# 4         1.000000
# ...            ...
# 7238      1.375000
# 7239      1.375000
# 7240      1.375000
# 7241      1.375000
# 7242      1.375000
#
# [7243 rows x 1 columns]

# %%
test.dtypes
# Out:
# user_id       int64
# article_id    int64
# dtype: object

# %%
y_pred.to_csv('solution_1.csv',index=False)
